# %%
#Importing libraries
from selenium import webdriver

# %%
from bs4 import BeautifulSoup

# %%
#Creating a webdriver of Chrome using selenium
driver= webdriver.Chrome('chromedriver.exe')

# %%
#Target website url
url='https://internshala.com/internships/data%20science-internship-in-mumbai'

# %%
#Loading the target website on webdriver
driver.get(url)

# %%
#Getting html soup of target website
soup=BeautifulSoup(driver.page_source,'lxml')

# %%
"""Scrapping 1) Job profile
             2) Company name
             3) Location
             4) Staring from
             5) Months of internship
             6) Stipend
             7) Job posting date
             8) Last date of applying 
             9) Link for specific internship respectively """
for ne in soup.find_all('div',{'class':'container-fluid individual_internship '}):
    for a in ne.find_all('a'):
        print(a.text.strip() if a.text.strip() !='View Details' else ''  )
  
    print(ne.table.tbody.text.strip())
    print('www.internshala.com'+ne.a['href'])
    print('*'*20)
    print('\n')
# Out:
# Data Analytics
# Hindustan Unilever Limited
# Mumbai
#
# Immediately
#
# 4 Months
#
# 25000 /Month
#
# 16 Jul'19
# 30 Jul'19
# www.internshala.com/internship/detail/data-analytics-internship-in-mumbai-at-hindustan-unilever-limited1563298842
# ********************
#
#
# System Design And Data Analytics
# IIT Bombay
# Mumbai
#
# Immediately
#
# 6 Months
#
# 3000-8000 /Month
#
# 1 Jul'19
# 5 Aug'19
# www.internshala.com/internship/detail/system-design-and-data-analytics-internship-in-mumbai-at-iit-bombay1561979208
# ********************
#
#
# Data Analytics
# Supr Daily (Swiggy Subsidiary)
# Mumbai
#
# Immediately
#
# 2 Months
#
# 15000 /Month
#
# 30 Jul'19
# 12 Aug'19
# www.internshala.com/internship/detail/data-analytics-internship-in-mumbai-at-supr-daily-swiggy-subsidiary1564400818
# ********************
#
#
# Data Analytics
# Srisa Techno
# Mumbai
#
# Immediately
#
# 3 Months
#
# 5000 /Month
#
# 29 Jul'19
# 11 Aug'19
# www.internshala.com/internship/detail/data-analytics-internship-in-mumbai-at-srisa-techno1564294442
# ********************
#
#
# BI System Analysis & Development (Business Intelligence)
# Merilent Interactive
# Mumbai
#
# Immediately
#
# 6 Months
#
# 5000 /Month
#
# 28 Jul'19
# 10 Aug'19
# www.internshala.com/internship/detail/bi-system-analysis-development-business-intelligence-internship-in-mumbai-at-merilent-interactive1564334789
# ********************
#
#
# Data Science
# Atri Technocrat
# Mumbai
#
# Immediately
#
# 6 Months
#
# 5000 /Month
#
# 27 Jul'19
# 8 Aug'19
# www.internshala.com/internship/detail/data-science-internship-in-mumbai-at-atri-technocrat1564062500
# ********************
#
#
# Research Analyst
# AAAAA Trade India Private Limited
# Mumbai
#
# Immediately
#
# 2 Months
#
# 5000 /Month
#
# 24 Jul'19
# 7 Aug'19
# www.internshala.com/internship/detail/research-analyst-internship-in-mumbai-at-aaaaa-trade-india-private-limited1563943448
# ********************
#
#
# Quantitative Research and Trading
# AlphaGrep Securities
# Mumbai
#
# Immediately
#
# 6 Months
#
# 10000 /Month
#
# 23 Jul'19
# 5 Aug'19
# www.internshala.com/internship/detail/quantitative-research-and-trading-internship-in-mumbai-at-alphagrep-securities1563972775
# ********************
#
#
# System Analysis
# Instinct Innovations
# Mumbai
#
# Immediately
#
# 3 Months
#
# 12000-15000 /Month
#
# 21 Jul'19
# 3 Aug'19
# www.internshala.com/internship/detail/system-analysis-internship-in-mumbai-at-instinct-innovations1563639383
# ********************
#
#
# Data Visualization And Web Scrapping
# MUni Campus
# Mumbai
#
# Immediately
#
# 4 Months
#
# 8000-10000 /Month
#
# 19 Jul'19
# 1 Aug'19
# www.internshala.com/internship/detail/data-visualization-and-web-scrapping-internship-in-mumbai-at-muni-campus1563450745
# ********************
#
#
# Business Analysis
# Prashaste Education And Management Consultancy Private Limited
# Mumbai
#
# Immediately
#
# 3 Months
#
# 5000-8000 /Month
#
# 18 Jul'19
# 1 Aug'19
# www.internshala.com/internship/detail/business-analysis-internship-in-mumbai-at-prashaste-education-and-management-consultancy-private-limited1563474581
# ********************
#
#
# Data Analytics
# Connect And Heal
# Mumbai
#
# Immediately
#
# 3 Months
#
# 25000-28000 /Month
#
# 18 Jul'19
# 1 Aug'19
# www.internshala.com/internship/detail/data-analytics-internship-in-mumbai-at-connect-and-heal1563423731
# ********************
#
#
# Data Science
# StrataHive Services Private Limited
# Mumbai
#
# Immediately
#
# 3 Months
#
# 5000 /Month
#
# 17 Jul'19
# 31 Jul'19
# www.internshala.com/internship/detail/data-science-internship-in-mumbai-at-stratahive-services-private-limited1563373235
# ********************
#
#
# Machine Learning
# NeuronWoods
# Mumbai
#
# Immediately
#
# 3 Months
#
# 4000 /Month
#
# 17 Jul'19
# 31 Jul'19
# www.internshala.com/internship/detail/machine-learning-internship-in-mumbai-at-neuronwoods1563325369
# ********************
#
#
# Computer Vision & Image Processing (Deep Learning)
# Trium Info Solutions Private Limited
# Mumbai
#
# Immediately
#
# 6 Months
#
# 3500 /Month
#
# 17 Jul'19
# 20 Aug'19
# www.internshala.com/internship/detail/computer-vision-image-processing-deep-learning-internship-in-mumbai-at-trium-info-solutions-private-limited1562914640
# ********************
#
#
# Data Science
# Catallyst Executive Education Institute
# Mumbai
#
# Immediately
#
# 6 Months
#
# 5000 /Month
#
# 25 Jun'19
# 30 Jul'19
# www.internshala.com/internship/detail/data-science-internship-in-mumbai-at-catallyst-executive-education-institute1561456738
# ********************
